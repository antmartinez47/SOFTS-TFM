# %%
import pandas as pd
import os

# %%
df_list = [
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh1_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh1", 96), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh1_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh1", 192), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh1_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh1", 336), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh1_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh1", 720), True],
    
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh2_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 96), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh2_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 192), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh2_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 336), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTh2_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 720), True],
    
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm1_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm1", 96), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm1_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm1", 192), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm1_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm1", 336), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm1_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm1", 720), True],
    
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm2_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm2", 96), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm2_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm2", 192), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm2_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm2", 336), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "ETTm2_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTm2", 720), True],
    
    [pd.read_csv(os.path.join("checkpoints", "baseline", "traffic_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("traffic", 96), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "traffic_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("traffic", 192), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "traffic_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("traffic", 336), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "traffic_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("traffic", 720), True],
    
    [pd.read_csv(os.path.join("checkpoints", "baseline", "weather_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("weather", 96), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "weather_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("weather", 192), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "weather_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("weather", 336), False],
    [pd.read_csv(os.path.join("checkpoints", "baseline", "weather_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("weather", 720), True],
]

# %%
df_with_indices = []
aux = []
for i in df_list:
    df = i[0]
    index_tuple = i[1]
    do_avg = i[2]
    # Assign the tuple as a multi-level index to the dataframe
    df.index = pd.MultiIndex.from_tuples([index_tuple], names=['Dataset', 'Horizon'])
    # Append the dataframe to the list
    df_with_indices.append(df)
    aux.append(df)
    if do_avg == True:
        aux = pd.DataFrame(pd.concat(aux)).groupby(level=0).mean()
        aux.index = pd.MultiIndex.from_product([aux.index, ['Avg']], names=['Dataset', 'Horizon'])
        df_with_indices.append(aux)
        aux = []
        
df = pd.concat(df_with_indices)
df.columns.name = "Metric"
df = df.rename(columns={
    "train_mse" : "MSE (Train)", "train_mae" : "MAE (Train)", 
    "val_mse" : "MSE (Valid)", "val_mae" : "MAE (Valid)", 
    "test_mse" : "MSE (Test)", "test_mae" : "MAE (Test)",
    "elapsed_time" : "Elapsed Time (s)", "vram_usage_gb": "VRAM Usage (Gb)"
    })

# %%
# Function to apply bold to Avg rows
def highlight_avg(val):
    return ['font-weight: bold' if v[1] == 'Avg' else '' for v in val.index]

# Apply the style to the DataFrame
styled_df = df.style.background_gradient(cmap='YlGnBu').apply(highlight_avg, axis=0).set_table_styles(
    [
        {'selector': 'th', 'props': [('border', '2px solid black')]},  # Header borders
        {'selector': 'td', 'props': [('border', '1px solid gray')]},   # Cell borders
        {'selector': 'thead', 'props': [('border', '2px solid black')]},  # Outer header border
        {'selector': '.index_name', 'props': [('border', '2px solid black')]},  # Index border
        {'selector': 'tbody tr', 'props': [('border', '2px solid black')]},  # Row border
    ]
)

# Display the styled DataFrame (in a notebook or output to HTML)
styled_df
# Out:
# <style type="text/css">
# #T_d7701 th {
#   border: 2px solid black;
# }
# #T_d7701 td {
#   border: 1px solid gray;
# }
# #T_d7701 thead {
#   border: 2px solid black;
# }
# #T_d7701 .index_name {
#   border: 2px solid black;
# }
# #T_d7701 tbody tr {
#   border: 2px solid black;
# }
# #T_d7701_row0_col0 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_d7701_row0_col1, #T_d7701_row27_col1 {
#   background-color: #34a9c3;
#   color: #f1f1f1;
# }
# #T_d7701_row0_col2 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_d7701_row0_col3 {
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_d7701_row0_col4, #T_d7701_row6_col5, #T_d7701_row7_col1 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_d7701_row0_col5 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_d7701_row0_col6, #T_d7701_row1_col6, #T_d7701_row2_col6, #T_d7701_row3_col6, #T_d7701_row5_col6, #T_d7701_row5_col7, #T_d7701_row6_col6, #T_d7701_row6_col7, #T_d7701_row7_col6, #T_d7701_row7_col7, #T_d7701_row8_col6, #T_d7701_row10_col7, #T_d7701_row11_col7, #T_d7701_row12_col7, #T_d7701_row13_col7, #T_d7701_row15_col0, #T_d7701_row15_col2, #T_d7701_row15_col6, #T_d7701_row16_col6, #T_d7701_row17_col6, #T_d7701_row18_col6, #T_d7701_row20_col1, #T_d7701_row20_col3, #T_d7701_row21_col3, #T_d7701_row25_col4, #T_d7701_row25_col5 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_d7701_row0_col7, #T_d7701_row1_col7, #T_d7701_row2_col7 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_d7701_row1_col0 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_d7701_row1_col1, #T_d7701_row13_col1, #T_d7701_row13_col3 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_d7701_row1_col2 {
#   background-color: #2498c1;
#   color: #f1f1f1;
# }
# #T_d7701_row1_col3 {
#   background-color: #1f7ab5;
#   color: #f1f1f1;
# }
# #T_d7701_row1_col4, #T_d7701_row21_col7 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_d7701_row1_col5 {
#   background-color: #23499e;
#   color: #f1f1f1;
# }
# #T_d7701_row2_col0 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_d7701_row2_col1 {
#   background-color: #234c9f;
#   color: #f1f1f1;
# }
# #T_d7701_row2_col2, #T_d7701_row7_col5, #T_d7701_row20_col7 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_d7701_row2_col3 {
#   background-color: #253b97;
#   color: #f1f1f1;
# }
# #T_d7701_row2_col4 {
#   background-color: #162874;
#   color: #f1f1f1;
# }
# #T_d7701_row2_col5 {
#   background-color: #253595;
#   color: #f1f1f1;
# }
# #T_d7701_row3_col0 {
#   background-color: #1e86bb;
#   color: #f1f1f1;
# }
# #T_d7701_row3_col1 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_d7701_row3_col2, #T_d7701_row3_col3, #T_d7701_row3_col4, #T_d7701_row3_col5, #T_d7701_row8_col0, #T_d7701_row8_col1, #T_d7701_row23_col6, #T_d7701_row23_col7 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_d7701_row3_col7, #T_d7701_row15_col7, #T_d7701_row16_col7 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_d7701_row4_col0 {
#   background-color: #67c4be;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row4_col1 {
#   background-color: #225da8;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row4_col2, #T_d7701_row14_col4 {
#   background-color: #2073b2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row4_col3 {
#   background-color: #225aa6;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row4_col4 {
#   background-color: #253997;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row4_col5 {
#   background-color: #243d98;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row4_col6, #T_d7701_row9_col6, #T_d7701_row9_col7, #T_d7701_row14_col7, #T_d7701_row19_col6 {
#   background-color: #ffffd9;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row4_col7 {
#   background-color: #fdfed4;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row5_col0 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_d7701_row5_col1 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_d7701_row5_col2 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_d7701_row5_col3, #T_d7701_row21_col2 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_d7701_row5_col4, #T_d7701_row28_col3 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# #T_d7701_row5_col5 {
#   background-color: #44b7c4;
#   color: #f1f1f1;
# }
# #T_d7701_row6_col0 {
#   background-color: #3db2c4;
#   color: #f1f1f1;
# }
# #T_d7701_row6_col1 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_d7701_row6_col2, #T_d7701_row15_col1 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_d7701_row6_col3, #T_d7701_row25_col2 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_d7701_row6_col4 {
#   background-color: #2195c0;
#   color: #f1f1f1;
# }
# #T_d7701_row7_col0 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_d7701_row7_col2, #T_d7701_row22_col2, #T_d7701_row26_col4 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_d7701_row7_col3, #T_d7701_row23_col5 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_d7701_row7_col4 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_d7701_row8_col2 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_d7701_row8_col3, #T_d7701_row12_col3 {
#   background-color: #46b8c3;
#   color: #f1f1f1;
# }
# #T_d7701_row8_col4 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_d7701_row8_col5 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_d7701_row8_col7, #T_d7701_row10_col6, #T_d7701_row11_col6, #T_d7701_row22_col3 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_d7701_row9_col0 {
#   background-color: #2397c1;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row9_col1 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row9_col2 {
#   background-color: #e2f4b2;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row9_col3 {
#   background-color: #b4e2b6;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row9_col4 {
#   background-color: #1e88bc;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row9_col5 {
#   background-color: #2072b1;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row10_col0 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_d7701_row10_col1 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_d7701_row10_col2 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_d7701_row10_col3 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_d7701_row10_col4 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_d7701_row10_col5 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_d7701_row11_col0 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_d7701_row11_col1 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_d7701_row11_col2 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_d7701_row11_col3 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_d7701_row11_col4 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_d7701_row11_col5 {
#   background-color: #1e88bc;
#   color: #f1f1f1;
# }
# #T_d7701_row12_col0, #T_d7701_row16_col0, #T_d7701_row25_col1 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_d7701_row12_col1, #T_d7701_row18_col0 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_d7701_row12_col2 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# #T_d7701_row12_col4 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_d7701_row12_col5 {
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_d7701_row12_col6, #T_d7701_row13_col6 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_d7701_row13_col0, #T_d7701_row16_col5 {
#   background-color: #92d5b9;
#   color: #000000;
# }
# #T_d7701_row13_col2 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_d7701_row13_col4 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_d7701_row13_col5 {
#   background-color: #233390;
#   color: #f1f1f1;
# }
# #T_d7701_row14_col0 {
#   background-color: #d4eeb3;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row14_col1 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row14_col2 {
#   background-color: #92d5b9;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row14_col3 {
#   background-color: #55bec1;
#   color: #000000;
#   font-weight: bold;
# }
# #T_d7701_row14_col5 {
#   background-color: #2070b0;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_d7701_row14_col6 {
#   b

# %%
df_list = [
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "default_configs", "ETTh2_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 96, "Default"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "random_search", "ETTh2_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 96, "Random Search"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "hyperopt_tpe", "ETTh2_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 96, "TPE"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "bohb", "ETTh2_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 96, "BOHB"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "smac", "ETTh2_96_96", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 96, "SMAC"), False],

    [pd.read_csv(os.path.join("checkpoints", "hptunning", "default_configs", "ETTh2_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 192, "Default"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "random_search", "ETTh2_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 192, "Random Search"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "hyperopt_tpe", "ETTh2_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 192, "TPE"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "bohb", "ETTh2_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 192, "BOHB"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "smac", "ETTh2_96_192", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 192, "SMAC"), False],
    
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "default_configs", "ETTh2_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 336, "Default"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "random_search", "ETTh2_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 336, "Random Search"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "hyperopt_tpe", "ETTh2_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 336, "TPE"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "bohb", "ETTh2_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 336, "BOHB"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "smac", "ETTh2_96_336", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 336, "SMAC"), False],
    
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "default_configs", "ETTh2_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 720, "Default"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "random_search", "ETTh2_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 720, "Random Search"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "hyperopt_tpe", "ETTh2_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 720, "TPE"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "bohb", "ETTh2_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 720, "BOHB"), False],
    [pd.read_csv(os.path.join("checkpoints", "hptunning", "best_configs", "smac", "ETTh2_96_720", "best_metrics.csv")).drop("Unnamed: 0", axis=1), ("ETTh2", 720, "SMAC"), False],
]

# %%
df_with_indices = []
for i in df_list:
    df = i[0]
    index_tuple = i[1]
    # Assign the tuple as a multi-level index to the dataframe
    df.index = pd.MultiIndex.from_tuples([index_tuple], names=['Dataset', 'Horizon', 'Configuration'])
    # Append the dataframe to the list
    df_with_indices.append(df)

df = pd.concat(df_with_indices)
df.columns.name = "Metric"
df = df.rename(columns={
    "train_mse" : "MSE (Train)", "train_mae" : "MAE (Train)", 
    "val_mse" : "MSE (Valid)", "val_mae" : "MAE (Valid)", 
    "test_mse" : "MSE (Test)", "test_mae" : "MAE (Test)",
    "elapsed_time" : "Elapsed Time (s)", "vram_usage_gb": "VRAM Usage (Gb)"
    })

# %%
def highlight_min(s):
    '''
    Highlight the minimum in a Series yellow.
    '''
    is_min = s == s.min()
    return ['background-color: yellow' if v else '' for v in is_min]

def style_horizon_group(group):
    """
    Apply highlighting to a group of rows that share the same Horizon value.
    """
    return group.style.background_gradient().apply(highlight_min, subset=["MSE (Valid)", "MAE (Valid)", "MSE (Test)", "MAE (Test)"]).set_table_styles(
    [
        {'selector': 'th', 'props': [('border', '2px solid black')]},  # Header borders
        {'selector': 'td', 'props': [('border', '1px solid gray')]},   # Cell borders
        {'selector': 'thead', 'props': [('border', '2px solid black')]},  # Outer header border
        {'selector': '.index_name', 'props': [('border', '2px solid black')]},  # Index border
        {'selector': 'tbody tr', 'props': [('border', '2px solid black')]},  # Row border
    ]
)

# Apply styling for each group and concatenate the results
styled_dfs = []
for horizon, group in df.groupby(level='Horizon'):
    styled_dfs.append(style_horizon_group(group))

# If you're in a Jupyter Notebook, you can display the first styled dataframe as a test
styled_df = styled_dfs[0]

# %%
styled_dfs[0]
# Out:
# <style type="text/css">
# #T_871cd th {
#   border: 2px solid black;
# }
# #T_871cd td {
#   border: 1px solid gray;
# }
# #T_871cd thead {
#   border: 2px solid black;
# }
# #T_871cd .index_name {
#   border: 2px solid black;
# }
# #T_871cd tbody tr {
#   border: 2px solid black;
# }
# #T_871cd_row0_col0, #T_871cd_row0_col1, #T_871cd_row0_col2, #T_871cd_row0_col3, #T_871cd_row0_col6, #T_871cd_row1_col5, #T_871cd_row3_col4, #T_871cd_row3_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_871cd_row0_col4, #T_871cd_row1_col3, #T_871cd_row4_col2, #T_871cd_row4_col5 {
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: yellow;
# }
# #T_871cd_row0_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_871cd_row0_col7, #T_871cd_row1_col6, #T_871cd_row2_col0, #T_871cd_row2_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_871cd_row1_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_871cd_row1_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_871cd_row1_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_871cd_row1_col4, #T_871cd_row2_col4 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_871cd_row1_col7 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_871cd_row2_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_871cd_row2_col3, #T_871cd_row4_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_871cd_row2_col5, #T_871cd_row2_col6 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_871cd_row2_col7 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_871cd_row3_col0, #T_871cd_row3_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_871cd_row3_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_871cd_row3_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_871cd_row3_col5 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_871cd_row3_col6 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_871cd_row4_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_871cd_row4_col1, #T_871cd_row4_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_871cd_row4_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_871cd_row4_col6 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# </style>
# <table id="T_871cd">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_871cd_level0_col0" class="col_heading level0 col0" >MSE (Train)</th>
#       <th id="T_871cd_level0_col1" class="col_heading level0 col1" >MAE (Train)</th>
#       <th id="T_871cd_level0_col2" class="col_heading level0 col2" >MSE (Valid)</th>
#       <th id="T_871cd_level0_col3" class="col_heading level0 col3" >MAE (Valid)</th>
#       <th id="T_871cd_level0_col4" class="col_heading level0 col4" >MSE (Test)</th>
#       <th id="T_871cd_level0_col5" class="col_heading level0 col5" >MAE (Test)</th>
#       <th id="T_871cd_level0_col6" class="col_heading level0 col6" >Elapsed Time (s)</th>
#       <th id="T_871cd_level0_col7" class="col_heading level0 col7" >VRAM Usage (Gb)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Horizon</th>
#       <th class="index_name level2" >Configuration</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_871cd_level0_row0" class="row_heading level0 row0" rowspan="5">ETTh2</th>
#       <th id="T_871cd_level1_row0" class="row_heading level1 row0" rowspan="5">96</th>
#       <th id="T_871cd_level2_row0" class="row_heading level2 row0" >Default</th>
#       <td id="T_871cd_row0_col0" class="data row0 col0" >0.410234</td>
#       <td id="T_871cd_row0_col1" class="data row0 col1" >0.360379</td>
#       <td id="T_871cd_row0_col2" class="data row0 col2" >0.219535</td>
#       <td id="T_871cd_row0_col3" class="data row0 col3" >0.321358</td>
#       <td id="T_871cd_row0_col4" class="data row0 col4" >0.292143</td>
#       <td id="T_871cd_row0_col5" class="data row0 col5" >0.344028</td>
#       <td id="T_871cd_row0_col6" class="data row0 col6" >40.742506</td>
#       <td id="T_871cd_row0_col7" class="data row0 col7" >0.345703</td>
#     </tr>
#     <tr>
#       <th id="T_871cd_level2_row1" class="row_heading level2 row1" >Random Search</th>
#       <td id="T_871cd_row1_col0" class="data row1 col0" >0.397116</td>
#       <td id="T_871cd_row1_col1" class="data row1 col1" >0.358152</td>
#       <td id="T_871cd_row1_col2" class="data row1 col2" >0.212144</td>
#       <td id="T_871cd_row1_col3" class="data row1 col3" >0.315195</td>
#       <td id="T_871cd_row1_col4" class="data row1 col4" >0.296314</td>
#       <td id="T_871cd_row1_col5" class="data row1 col5" >0.347864</td>
#       <td id="T_871cd_row1_col6" class="data row1 col6" >5.346320</td>
#       <td id="T_871cd_row1_col7" class="data row1 col7" >0.453125</td>
#     </tr>
#     <tr>
#       <th id="T_871cd_level2_row2" class="row_heading level2 row2" >TPE</th>
#       <td id="T_871cd_row2_col0" class="data row2 col0" >0.365613</td>
#       <td id="T_871cd_row2_col1" class="data row2 col1" >0.346686</td>
#       <td id="T_871cd_row2_col2" class="data row2 col2" >0.211814</td>
#       <td id="T_871cd_row2_col3" class="data row2 col3" >0.315447</td>
#       <td id="T_871cd_row2_col4" class="data row2 col4" >0.296329</td>
#       <td id="T_871cd_row2_col5" class="data row2 col5" >0.345193</td>
#       <td id="T_871cd_row2_col6" class="data row2 col6" >17.533375</td>
#       <td id="T_871cd_row2_col7" class="data row2 col7" >0.449219</td>
#     </tr>
#     <tr>
#       <th id="T_871cd_level2_row3" class="row_heading level2 row3" >BOHB</th>
#       <td id="T_871cd_row3_col0" class="data row3 col0" >0.366316</td>
#       <td id="T_871cd_row3_col1" class="data row3 col1" >0.349595</td>
#       <td id="T_871cd_row3_col2" class="data row3 col2" >0.211700</td>
#       <td id="T_871cd_row3_col3" class="data row3 col3" >0.315287</td>
#       <td id="T_871cd_row3_col4" class="data row3 col4" >0.298768</td>
#       <td id="T_871cd_row3_col5" class="data row3 col5" >0.347242</td>
#       <td id="T_871cd_row3_col6" class="data row3 col6" >25.626479</td>
#       <td id="T_871cd_row3_col7" class="data row3 col7" >0.683594</td>
#     </tr>
#     <tr>
#       <th id="T_871cd_level2_row4" class="row_heading level2 row4" >SMAC</th>
#       <td id="T_871cd_row4_col0" class="data row4 col0" >0.370450</td>
#       <td id="T_871cd_row4_col1" class="data row4 col1" >0.349363</td>
#       <td id="T_871cd_row4_col2" class="data row4 col2" >0.211654</td>
#       <td id="T_871cd_row4_col3" class="data row4 col3" >0.315648</td>
#       <td id="T_871cd_row4_col4" class="data row4 col4" >0.292415</td>
#       <td id="T_871cd_row4_col5" class="data row4 col5" >0.343790</td>
#       <td id="T_871cd_row4_col6" class="data row4 col6" >9.343482</td>
#       <td id="T_871cd_row4_col7" class="data row4 col7" >0.412109</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_dfs[1]
# Out:
# <style type="text/css">
# #T_d9a2d th {
#   border: 2px solid black;
# }
# #T_d9a2d td {
#   border: 1px solid gray;
# }
# #T_d9a2d thead {
#   border: 2px solid black;
# }
# #T_d9a2d .index_name {
#   border: 2px solid black;
# }
# #T_d9a2d tbody tr {
#   border: 2px solid black;
# }
# #T_d9a2d_row0_col0, #T_d9a2d_row0_col1, #T_d9a2d_row0_col2, #T_d9a2d_row0_col3, #T_d9a2d_row0_col6, #T_d9a2d_row1_col7, #T_d9a2d_row3_col4, #T_d9a2d_row3_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d9a2d_row0_col4, #T_d9a2d_row0_col5, #T_d9a2d_row1_col2, #T_d9a2d_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: yellow;
# }
# #T_d9a2d_row0_col7, #T_d9a2d_row1_col6, #T_d9a2d_row4_col0, #T_d9a2d_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d9a2d_row1_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_d9a2d_row1_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_d9a2d_row1_col4 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_d9a2d_row1_col5 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_d9a2d_row2_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_d9a2d_row2_col1, #T_d9a2d_row2_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_d9a2d_row2_col3 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_d9a2d_row2_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_d9a2d_row2_col5 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_d9a2d_row2_col6 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_d9a2d_row2_col7 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_d9a2d_row3_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_d9a2d_row3_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d9a2d_row3_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_d9a2d_row3_col3 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_d9a2d_row3_col6 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_d9a2d_row3_col7 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_d9a2d_row4_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_d9a2d_row4_col3 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_d9a2d_row4_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_d9a2d_row4_col5 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_d9a2d_row4_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d9a2d_row4_col7 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d9a2d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_d9a2d_level0_col0" class="col_heading level0 col0" >MSE (Train)</th>
#       <th id="T_d9a2d_level0_col1" class="col_heading level0 col1" >MAE (Train)</th>
#       <th id="T_d9a2d_level0_col2" class="col_heading level0 col2" >MSE (Valid)</th>
#       <th id="T_d9a2d_level0_col3" class="col_heading level0 col3" >MAE (Valid)</th>
#       <th id="T_d9a2d_level0_col4" class="col_heading level0 col4" >MSE (Test)</th>
#       <th id="T_d9a2d_level0_col5" class="col_heading level0 col5" >MAE (Test)</th>
#       <th id="T_d9a2d_level0_col6" class="col_heading level0 col6" >Elapsed Time (s)</th>
#       <th id="T_d9a2d_level0_col7" class="col_heading level0 col7" >VRAM Usage (Gb)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Horizon</th>
#       <th class="index_name level2" >Configuration</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9a2d_level0_row0" class="row_heading level0 row0" rowspan="5">ETTh2</th>
#       <th id="T_d9a2d_level1_row0" class="row_heading level1 row0" rowspan="5">192</th>
#       <th id="T_d9a2d_level2_row0" class="row_heading level2 row0" >Default</th>
#       <td id="T_d9a2d_row0_col0" class="data row0 col0" >0.534086</td>
#       <td id="T_d9a2d_row0_col1" class="data row0 col1" >0.418830</td>
#       <td id="T_d9a2d_row0_col2" class="data row0 col2" >0.280490</td>
#       <td id="T_d9a2d_row0_col3" class="data row0 col3" >0.362719</td>
#       <td id="T_d9a2d_row0_col4" class="data row0 col4" >0.384006</td>
#       <td id="T_d9a2d_row0_col5" class="data row0 col5" >0.404180</td>
#       <td id="T_d9a2d_row0_col6" class="data row0 col6" >44.200587</td>
#       <td id="T_d9a2d_row0_col7" class="data row0 col7" >0.347656</td>
#     </tr>
#     <tr>
#       <th id="T_d9a2d_level2_row1" class="row_heading level2 row1" >Random Search</th>
#       <td id="T_d9a2d_row1_col0" class="data row1 col0" >0.499825</td>
#       <td id="T_d9a2d_row1_col1" class="data row1 col1" >0.404978</td>
#       <td id="T_d9a2d_row1_col2" class="data row1 col2" >0.262888</td>
#       <td id="T_d9a2d_row1_col3" class="data row1 col3" >0.350322</td>
#       <td id="T_d9a2d_row1_col4" class="data row1 col4" >0.399926</td>
#       <td id="T_d9a2d_row1_col5" class="data row1 col5" >0.409671</td>
#       <td id="T_d9a2d_row1_col6" class="data row1 col6" >11.322594</td>
#       <td id="T_d9a2d_row1_col7" class="data row1 col7" >0.533203</td>
#     </tr>
#     <tr>
#       <th id="T_d9a2d_level2_row2" class="row_heading level2 row2" >TPE</th>
#       <td id="T_d9a2d_row2_col0" class="data row2 col0" >0.490576</td>
#       <td id="T_d9a2d_row2_col1" class="data row2 col1" >0.404570</td>
#       <td id="T_d9a2d_row2_col2" class="data row2 col2" >0.267601</td>
#       <td id="T_d9a2d_row2_col3" class="data row2 col3" >0.355022</td>
#       <td id="T_d9a2d_row2_col4" class="data row2 col4" >0.391128</td>
#       <td id="T_d9a2d_row2_col5" class="data row2 col5" >0.408234</td>
#       <td id="T_d9a2d_row2_col6" class="data row2 col6" >19.703879</td>
#       <td id="T_d9a2d_row2_col7" class="data row2 col7" >0.453125</td>
#     </tr>
#     <tr>
#       <th id="T_d9a2d_level2_row3" class="row_heading level2 row3" >BOHB</th>
#       <td id="T_d9a2d_row3_col0" class="data row3 col0" >0.486798</td>
#       <td id="T_d9a2d_row3_col1" class="data row3 col1" >0.404469</td>
#       <td id="T_d9a2d_row3_col2" class="data row3 col2" >0.269866</td>
#       <td id="T_d9a2d_row3_col3" class="data row3 col3" >0.355969</td>
#       <td id="T_d9a2d_row3_col4" class="data row3 col4" >0.406130</td>
#       <td id="T_d9a2d_row3_col5" class="data row3 col5" >0.412563</td>
#       <td id="T_d9a2d_row3_col6" class="data row3 col6" >12.548785</td>
#       <td id="T_d9a2d_row3_col7" class="data row3 col7" >0.404297</td>
#     </tr>
#     <tr>
#       <th id="T_d9a2d_level2_row4" class="row_heading level2 row4" >SMAC</th>
#       <td id="T_d9a2d_row4_col0" class="data row4 col0" >0.475855</td>
#       <td id="T_d9a2d_row4_col1" class="data row4 col1" >0.399406</td>
#       <td id="T_d9a2d_row4_col2" class="data row4 col2" >0.267876</td>
#       <td id="T_d9a2d_row4_col3" class="data row4 col3" >0.354973</td>
#       <td id="T_d9a2d_row4_col4" class="data row4 col4" >0.391913</td>
#       <td id="T_d9a2d_row4_col5" class="data row4 col5" >0.406111</td>
#       <td id="T_d9a2d_row4_col6" class="data row4 col6" >14.695835</td>
#       <td id="T_d9a2d_row4_col7" class="data row4 col7" >0.515625</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_dfs[2]
# Out:
# <style type="text/css">
# #T_61521 th {
#   border: 2px solid black;
# }
# #T_61521 td {
#   border: 1px solid gray;
# }
# #T_61521 thead {
#   border: 2px solid black;
# }
# #T_61521 .index_name {
#   border: 2px solid black;
# }
# #T_61521 tbody tr {
#   border: 2px solid black;
# }
# #T_61521_row0_col0, #T_61521_row0_col1, #T_61521_row0_col2, #T_61521_row2_col6, #T_61521_row3_col3, #T_61521_row4_col4, #T_61521_row4_col5, #T_61521_row4_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_61521_row0_col3 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_61521_row0_col4, #T_61521_row0_col5, #T_61521_row2_col3, #T_61521_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: yellow;
# }
# #T_61521_row0_col6 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_61521_row0_col7, #T_61521_row3_col6, #T_61521_row4_col0, #T_61521_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_61521_row1_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_61521_row1_col1, #T_61521_row2_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_61521_row1_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_61521_row1_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_61521_row1_col4 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_61521_row1_col5 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_61521_row1_col6 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_61521_row1_col7 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_61521_row2_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_61521_row2_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_61521_row2_col4 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_61521_row2_col5 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_61521_row2_col7 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_61521_row3_col0, #T_61521_row3_col7 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_61521_row3_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_61521_row3_col2 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_61521_row3_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_61521_row3_col5 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_61521_row4_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_61521_row4_col6 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# </style>
# <table id="T_61521">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_61521_level0_col0" class="col_heading level0 col0" >MSE (Train)</th>
#       <th id="T_61521_level0_col1" class="col_heading level0 col1" >MAE (Train)</th>
#       <th id="T_61521_level0_col2" class="col_heading level0 col2" >MSE (Valid)</th>
#       <th id="T_61521_level0_col3" class="col_heading level0 col3" >MAE (Valid)</th>
#       <th id="T_61521_level0_col4" class="col_heading level0 col4" >MSE (Test)</th>
#       <th id="T_61521_level0_col5" class="col_heading level0 col5" >MAE (Test)</th>
#       <th id="T_61521_level0_col6" class="col_heading level0 col6" >Elapsed Time (s)</th>
#       <th id="T_61521_level0_col7" class="col_heading level0 col7" >VRAM Usage (Gb)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Horizon</th>
#       <th class="index_name level2" >Configuration</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61521_level0_row0" class="row_heading level0 row0" rowspan="5">ETTh2</th>
#       <th id="T_61521_level1_row0" class="row_heading level1 row0" rowspan="5">336</th>
#       <th id="T_61521_level2_row0" class="row_heading level2 row0" >Default</th>
#       <td id="T_61521_row0_col0" class="data row0 col0" >0.638479</td>
#       <td id="T_61521_row0_col1" class="data row0 col1" >0.461363</td>
#       <td id="T_61521_row0_col2" class="data row0 col2" >0.364043</td>
#       <td id="T_61521_row0_col3" class="data row0 col3" >0.408450</td>
#       <td id="T_61521_row0_col4" class="data row0 col4" >0.421392</td>
#       <td id="T_61521_row0_col5" class="data row0 col5" >0.433185</td>
#       <td id="T_61521_row0_col6" class="data row0 col6" >43.780941</td>
#       <td id="T_61521_row0_col7" class="data row0 col7" >0.347656</td>
#     </tr>
#     <tr>
#       <th id="T_61521_level2_row1" class="row_heading level2 row1" >Random Search</th>
#       <td id="T_61521_row1_col0" class="data row1 col0" >0.477715</td>
#       <td id="T_61521_row1_col1" class="data row1 col1" >0.404953</td>
#       <td id="T_61521_row1_col2" class="data row1 col2" >0.339104</td>
#       <td id="T_61521_row1_col3" class="data row1 col3" >0.396931</td>
#       <td id="T_61521_row1_col4" class="data row1 col4" >0.444399</td>
#       <td id="T_61521_row1_col5" class="data row1 col5" >0.440987</td>
#       <td id="T_61521_row1_col6" class="data row1 col6" >92.808857</td>
#       <td id="T_61521_row1_col7" class="data row1 col7" >0.382812</td>
#     </tr>
#     <tr>
#       <th id="T_61521_level2_row2" class="row_heading level2 row2" >TPE</th>
#       <td id="T_61521_row2_col0" class="data row2 col0" >0.478980</td>
#       <td id="T_61521_row2_col1" class="data row2 col1" >0.404867</td>
#       <td id="T_61521_row2_col2" class="data row2 col2" >0.336105</td>
#       <td id="T_61521_row2_col3" class="data row2 col3" >0.393136</td>
#       <td id="T_61521_row2_col4" class="data row2 col4" >0.445675</td>
#       <td id="T_61521_row2_col5" class="data row2 col5" >0.440149</td>
#       <td id="T_61521_row2_col6" class="data row2 col6" >161.437109</td>
#       <td id="T_61521_row2_col7" class="data row2 col7" >0.546875</td>
#     </tr>
#     <tr>
#       <th id="T_61521_level2_row3" class="row_heading level2 row3" >BOHB</th>
#       <td id="T_61521_row3_col0" class="data row3 col0" >0.595076</td>
#       <td id="T_61521_row3_col1" class="data row3 col1" >0.452220</td>
#       <td id="T_61521_row3_col2" class="data row3 col2" >0.356088</td>
#       <td id="T_61521_row3_col3" class="data row3 col3" >0.409265</td>
#       <td id="T_61521_row3_col4" class="data row3 col4" >0.431909</td>
#       <td id="T_61521_row3_col5" class="data row3 col5" >0.441120</td>
#       <td id="T_61521_row3_col6" class="data row3 col6" >19.796936</td>
#       <td id="T_61521_row3_col7" class="data row3 col7" >0.568359</td>
#     </tr>
#     <tr>
#       <th id="T_61521_level2_row4" class="row_heading level2 row4" >SMAC</th>
#       <td id="T_61521_row4_col0" class="data row4 col0" >0.476081</td>
#       <td id="T_61521_row4_col1" class="data row4 col1" >0.404529</td>
#       <td id="T_61521_row4_col2" class="data row4 col2" >0.335058</td>
#       <td id="T_61521_row4_col3" class="data row4 col3" >0.394308</td>
#       <td id="T_61521_row4_col4" class="data row4 col4" >0.458728</td>
#       <td id="T_61521_row4_col5" class="data row4 col5" >0.446903</td>
#       <td id="T_61521_row4_col6" class="data row4 col6" >67.506242</td>
#       <td id="T_61521_row4_col7" class="data row4 col7" >0.648438</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_dfs[3]
# Out:
# <style type="text/css">
# #T_0875e th {
#   border: 2px solid black;
# }
# #T_0875e td {
#   border: 1px solid gray;
# }
# #T_0875e thead {
#   border: 2px solid black;
# }
# #T_0875e .index_name {
#   border: 2px solid black;
# }
# #T_0875e tbody tr {
#   border: 2px solid black;
# }
# #T_0875e_row0_col0, #T_0875e_row0_col1, #T_0875e_row0_col2, #T_0875e_row0_col3, #T_0875e_row1_col6, #T_0875e_row2_col7, #T_0875e_row3_col4, #T_0875e_row3_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0875e_row0_col4, #T_0875e_row0_col5, #T_0875e_row2_col2, #T_0875e_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: yellow;
# }
# #T_0875e_row0_col6 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_0875e_row0_col7, #T_0875e_row2_col6, #T_0875e_row3_col0, #T_0875e_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0875e_row1_col0, #T_0875e_row1_col5 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_0875e_row1_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_0875e_row1_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_0875e_row1_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_0875e_row1_col4, #T_0875e_row3_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_0875e_row1_col7 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_0875e_row2_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_0875e_row2_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_0875e_row2_col4 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_0875e_row2_col5 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_0875e_row3_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_0875e_row3_col6 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_0875e_row3_col7 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_0875e_row4_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_0875e_row4_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_0875e_row4_col2 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_0875e_row4_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_0875e_row4_col4 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_0875e_row4_col5 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_0875e_row4_col6 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_0875e_row4_col7 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0875e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_0875e_level0_col0" class="col_heading level0 col0" >MSE (Train)</th>
#       <th id="T_0875e_level0_col1" class="col_heading level0 col1" >MAE (Train)</th>
#       <th id="T_0875e_level0_col2" class="col_heading level0 col2" >MSE (Valid)</th>
#       <th id="T_0875e_level0_col3" class="col_heading level0 col3" >MAE (Valid)</th>
#       <th id="T_0875e_level0_col4" class="col_heading level0 col4" >MSE (Test)</th>
#       <th id="T_0875e_level0_col5" class="col_heading level0 col5" >MAE (Test)</th>
#       <th id="T_0875e_level0_col6" class="col_heading level0 col6" >Elapsed Time (s)</th>
#       <th id="T_0875e_level0_col7" class="col_heading level0 col7" >VRAM Usage (Gb)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Horizon</th>
#       <th class="index_name level2" >Configuration</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0875e_level0_row0" class="row_heading level0 row0" rowspan="5">ETTh2</th>
#       <th id="T_0875e_level1_row0" class="row_heading level1 row0" rowspan="5">720</th>
#       <th id="T_0875e_level2_row0" class="row_heading level2 row0" >Default</th>
#       <td id="T_0875e_row0_col0" class="data row0 col0" >0.748589</td>
#       <td id="T_0875e_row0_col1" class="data row0 col1" >0.520266</td>
#       <td id="T_0875e_row0_col2" class="data row0 col2" >0.568995</td>
#       <td id="T_0875e_row0_col3" class="data row0 col3" >0.518753</td>
#       <td id="T_0875e_row0_col4" class="data row0 col4" >0.427919</td>
#       <td id="T_0875e_row0_col5" class="data row0 col5" >0.441015</td>
#       <td id="T_0875e_row0_col6" class="data row0 col6" >44.715349</td>
#       <td id="T_0875e_row0_col7" class="data row0 col7" >0.353516</td>
#     </tr>
#     <tr>
#       <th id="T_0875e_level2_row1" class="row_heading level2 row1" >Random Search</th>
#       <td id="T_0875e_row1_col0" class="data row1 col0" >0.702288</td>
#       <td id="T_0875e_row1_col1" class="data row1 col1" >0.499291</td>
#       <td id="T_0875e_row1_col2" class="data row1 col2" >0.533264</td>
#       <td id="T_0875e_row1_col3" class="data row1 col3" >0.501897</td>
#       <td id="T_0875e_row1_col4" class="data row1 col4" >0.446702</td>
#       <td id="T_0875e_row1_col5" class="data row1 col5" >0.451928</td>
#       <td id="T_0875e_row1_col6" class="data row1 col6" >49.351017</td>
#       <td id="T_0875e_row1_col7" class="data row1 col7" >0.521484</td>
#     </tr>
#     <tr>
#       <th id="T_0875e_level2_row2" class="row_heading level2 row2" >TPE</th>
#       <td id="T_0875e_row2_col0" class="data row2 col0" >0.683148</td>
#       <td id="T_0875e_row2_col1" class="data row2 col1" >0.491133</td>
#       <td id="T_0875e_row2_col2" class="data row2 col2" >0.525562</td>
#       <td id="T_0875e_row2_col3" class="data row2 col3" >0.499786</td>
#       <td id="T_0875e_row2_col4" class="data row2 col4" >0.454131</td>
#       <td id="T_0875e_row2_col5" class="data row2 col5" >0.453349</td>
#       <td id="T_0875e_row2_col6" class="data row2 col6" >24.459963</td>
#       <td id="T_0875e_row2_col7" class="data row2 col7" >0.623047</td>
#     </tr>
#     <tr>
#       <th id="T_0875e_level2_row3" class="row_heading level2 row3" >BOHB</th>
#       <td id="T_0875e_row3_col0" class="data row3 col0" >0.664676</td>
#       <td id="T_0875e_row3_col1" class="data row3 col1" >0.482520</td>
#       <td id="T_0875e_row3_col2" class="data row3 col2" >0.540320</td>
#       <td id="T_0875e_row3_col3" class="data row3 col3" >0.507711</td>
#       <td id="T_0875e_row3_col4" class="data row3 col4" >0.473141</td>
#       <td id="T_0875e_row3_col5" class="data row3 col5" >0.465408</td>
#       <td id="T_0875e_row3_col6" class="data row3 col6" >42.592743</td>
#       <td id="T_0875e_row3_col7" class="data row3 col7" >0.548828</td>
#     </tr>
#     <tr>
#       <th id="T_0875e_level2_row4" class="row_heading level2 row4" >SMAC</th>
#       <td id="T_0875e_row4_col0" class="data row4 col0" >0.685711</td>
#       <td id="T_0875e_row4_col1" class="data row4 col1" >0.495052</td>
#       <td id="T_0875e_row4_col2" class="data row4 col2" >0.536301</td>
#       <td id="T_0875e_row4_col3" class="data row4 col3" >0.504746</td>
#       <td id="T_0875e_row4_col4" class="data row4 col4" >0.446192</td>
#       <td id="T_0875e_row4_col5" class="data row4 col5" >0.455003</td>
#       <td id="T_0875e_row4_col6" class="data row4 col6" >35.435493</td>
#       <td id="T_0875e_row4_col7" class="data row4 col7" >0.531250</td>
#     </tr>
#   </tbody>
# </table>
